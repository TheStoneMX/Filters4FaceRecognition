# %%
import keras_vggface
from PIL import Image
from numpy import asarray
import PIL
import os, sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

from keras_vggface.utils import preprocess_input
from keras_vggface.vggface import VGGFace
# Out:
# Using TensorFlow backend.

# %%
import keras_vggface

from keras_vggface.utils import preprocess_input
from keras_vggface.vggface import VGGFace

fig, ax = plt.subplots(6, # rows 
                       5,  # columns
                       figsize=(50, 50)) 

files = os.listdir('faces/')
total_files = len(files)

for i in range(6):          
    for j in range(5):
        img = cv2.imread('faces/' + files[i])
        img = cv2.resize(img, (224,224))
        img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        img = np.array(img).astype(np.float32)/255.0
        mean = img.mean()
        img = img - mean
        #mean = pixels.mean()
        ax[i, j].imshow(img)
# Out:
# W0712 15:35:37.296090 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.298607 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.300798 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.302802 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.304857 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.306799 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.308722 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.310827 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.312746 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.314685 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.316802 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.318732 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.320664 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.322624 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.324639 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.326583 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.328954 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.331197 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.333802 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.336045 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.338114 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.340095 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.342358 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.344316 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.346511 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.349586 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.351663 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.353669 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.355745 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:35:37.357971 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import keras_vggface

from keras_vggface.utils import preprocess_input
from keras_vggface.vggface import VGGFace

fig, ax = plt.subplots(6, # rows 
                       5,  # columns
                       figsize=(50, 50)) 

files = os.listdir('faces/')
total_files = len(files)

for i in range(6):          
    for j in range(5):
        img = cv2.imread('faces/' + files[i])
        img = cv2.resize(img, (224,224))
        img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        img = np.array(img).astype(np.float32)/255.0
        ax[i, j].imshow(img)

# %%
import keras_vggface

from keras_vggface.utils import preprocess_input
from keras_vggface.vggface import VGGFace

fig, ax = plt.subplots(6, # rows 
                       5,  # columns
                       figsize=(50, 50)) 

files = os.listdir('faces/')
total_files = len(files)

for i in range(6):          
    for j in range(5):
        img = cv2.imread('faces/' + files[i])
        img = cv2.resize(img, (224,224))
        img = np.array(img).astype(np.float32)
        img = keras_vggface.utils.preprocess_input(img)
        ax[i, j].imshow(img)
# Out:
# W0712 16:15:48.309188 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.311876 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.314270 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.317027 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.319755 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.322421 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.325036 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.327663 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.329828 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.332131 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.334965 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.338235 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.340522 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.342834 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.344974 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.347247 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.349308 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.351374 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.353589 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.356179 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.358442 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.361088 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.363296 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.365581 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.367822 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.369893 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.371959 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.374199 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.376239 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 16:15:48.378389 140460324841280 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import keras_vggface

from keras_vggface.utils import preprocess_input
from keras_vggface.vggface import VGGFace

def pre_process(img): 
    img[:,:,0] = img[:,:,0] - 103.939
    img[:,:,1] = img[:,:,0] - 116.779
    img[:,:,2] = img[:,:,0] - 123.68
    return img

fig, ax = plt.subplots(6, # rows 
                       5,  # columns
                       figsize=(50, 50)) 

files = os.listdir('faces/')
total_files = len(files)

for i in range(6):          
    for j in range(5):
        img = cv2.imread('faces/' + files[i])
        img = cv2.resize(img, (224,224))
        img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        img = np.array(img).astype(np.float)
        img = pre_process(img)
        ax[i, j].imshow(img)
# Out:
# W0712 15:03:49.769523 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.772597 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.775362 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.778190 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.780837 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.783581 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.786257 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.788795 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.791513 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.794035 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.796656 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.802048 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.808501 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.814280 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.819280 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.823905 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.828050 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.832334 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.836299 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.839718 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.843022 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.846163 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.849313 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.852431 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.855505 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.858407 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.861529 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.864525 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.868489 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0712 15:03:49.871462 140707613960000 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
fig, ax = plt.subplots(6, # rows 
                       5,  # columns
                       figsize=(50, 50)) 

files = os.listdir('faces/')
total_files = len(files)

for i in range(6):          
    for j in range(5):
        img = cv2.imread('faces/' + files[i])
        img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (224,224))
        
        pixels = asarray(img)
        # convert from integers to floats
        pixels = pixels.astype('float32')
        # calculate global mean
        mean = pixels.mean()
        # global centering of pixels
        pixels = pixels - mean
        # img = Image.fromarray(pixels)

        ax[i, j].imshow(pixels)
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0711 19:16:55.599743 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.604552 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.607502 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.610210 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.614100 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.617080 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.620046 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.622689 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.624949 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.627156 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.629491 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.632168 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.638242 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.641760 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.644831 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.650412 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.654279 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.657127 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.659514 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.661942 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.664493 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.666855 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.670142 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.672761 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.675303 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.677726 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.680707 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.683315 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.685826 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:16:55.688430 140561746671424 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import keras_vggface

from keras_vggface.utils import preprocess_input
from keras_vggface.vggface import VGGFace

fig, ax = plt.subplots(6, # rows 
                       5,  # columns
                       figsize=(50, 50)) 

files = os.listdir('faces/')
total_files = len(files)

for i in range(6):          
    for j in range(5):
        img = cv2.imread('faces/' + files[i])
        img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (224,224))
        img = cv2.Canny(img,40,55,apertureSize = 3)
        #img = cv2.addWeighted ( img, 4, cv2.GaussianBlur( img , (0,0) , 5) ,-4 ,128)
        img = np.array(img).astype(np.float)
        img = keras_vggface.utils.preprocess_input(img)
        ax[i, j].imshow(img)

# %%
import keras_vggface

from keras_vggface.utils import preprocess_input
from keras_vggface.vggface import VGGFace

fig, ax = plt.subplots(6, # rows 
                       5,  # columns
                       figsize=(50, 50)) 

files = os.listdir('faces/')
total_files = len(files)

for i in range(6):          
    for j in range(5):
        img = cv2.imread('faces/' + files[i])
        img = cv2.resize(img, (224,224))
        img = np.array(img).astype(np.float)
        img = keras_vggface.utils.preprocess_input(img)
        ax[i, j].imshow(img)
# Out:
# W0711 17:24:50.397235 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.400977 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.404143 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.407239 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.410193 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.413115 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.416188 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.419515 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.427474 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.434058 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.440122 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.446557 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.451120 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.455138 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.458925 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.462600 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.466935 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.475404 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.478872 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.483726 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.487575 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.490750 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.496848 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.502835 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.506221 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.509189 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.512048 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.515927 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.519488 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 17:24:50.522542 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import keras_vggface

from keras_vggface.utils import preprocess_input
from keras_vggface.vggface import VGGFace

fig, ax = plt.subplots(6, # rows 
                       5,  # columns
                       figsize=(50, 50)) 

files = os.listdir('faces/')
total_files = len(files)

for i in range(6):          
    for j in range(5):
        img = cv2.imread('faces/' + files[i])
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
        img = cv2.resize(img, (197,197))
        img = cv2.addWeighted ( img, 4, cv2.GaussianBlur( img , (0,0) , 5) ,-4 ,128)
        img = np.array(img).astype(np.float)
        img = keras_vggface.utils.preprocess_input(img)
        ax[i, j].imshow(img)
# Out:
# W0711 18:01:39.032142 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.036972 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.042095 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.046078 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.050953 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.055678 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.060587 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.065427 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.070115 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.075980 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.081379 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.086276 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.090921 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.096158 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.101695 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.106720 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.111358 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.116654 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.120912 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.129315 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.133893 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.137501 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.141116 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.144637 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.148375 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.152070 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.156184 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.163164 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.168524 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:01:39.173615 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import keras_vggface

from keras_vggface.utils import preprocess_input
from keras_vggface.vggface import VGGFace

fig, ax = plt.subplots(6, # rows 
                       5,  # columns
                       figsize=(50, 50)) 

files = os.listdir('faces/')
total_files = len(files)

for i in range(6):          
    for j in range(5):
        img = cv2.imread('faces/' + files[i])
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
        img = cv2.resize(img, (197,197))
        img = cv2.addWeighted ( img, 4, cv2.GaussianBlur( img , (0,0) , 30) ,-4 ,128)
        img = np.array(img).astype(np.float)
        img = keras_vggface.utils.preprocess_input(img)
        ax[i, j].imshow(img)
# Out:
# W0711 18:33:34.376234 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:34.429288 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:34.480312 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:34.529608 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:34.576117 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:34.618726 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:34.660469 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:34.700645 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:34.741815 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:34.784138 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:34.826153 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:34.870377 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:34.914790 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:34.960752 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:35.004153 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:35.049418 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:35.092392 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:35.135659 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:35.181300 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:35.226557 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:35.270582 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:35.316874 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:35.362177 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:35.406429 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:35.450975 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:35.493463 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:35.533865 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:35.576353 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:35.618174 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 18:33:35.661227 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import keras_vggface

from keras_vggface.utils import preprocess_input
from keras_vggface.vggface import VGGFace

fig, ax = plt.subplots(6, # rows 
                       5,  # columns
                       figsize=(50, 50)) 

files = os.listdir('faces/')
total_files = len(files)

for i in range(6):          
    for j in range(5):
        img = cv2.imread('faces/' + files[i])
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
        img = cv2.resize(img, (197,197))
        img = cv2.addWeighted ( img, 4, cv2.GaussianBlur( img , (9,9) , 10) ,-4 ,128)
        img = np.array(img).astype(np.float)
        img = keras_vggface.utils.preprocess_input(img)
        ax[i, j].imshow(img)
# Out:
# W0711 19:13:56.205637 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.208891 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.212100 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.215023 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.217958 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.220779 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.223545 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.226444 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.232607 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.236025 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.239962 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.243691 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.249445 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.260792 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.266947 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.274236 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.280838 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.285468 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.289267 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.295973 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.309111 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.312773 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.320938 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.330826 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.335095 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.338724 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.341741 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.344622 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.347095 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0711 19:13:56.349829 139870434772800 image.py:700] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
